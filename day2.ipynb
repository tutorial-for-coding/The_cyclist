# %%
#continute from day 1

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True

# sun_img = pygame.image.load("./images/sun.png") ##commented this line out
background_img =  pygame.image.load("./Assets/BG/bg 01.png") ##load a different background

while running == True:
    
    screen.blit(background_img, (0, 0)) # background first
    # screen.blit(sun_img, (100, 100)) #comment displaying the sun as well


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.update()

##conclusion: the image is not loading fully

# %%
#to properly fit the background image in the screen

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True

# sun_img = pygame.image.load("./images/sun.png") ##commented this line out
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (800, 800))##we can specify the resolution we want the image to load at to match that of our screen

while running == True:
    
    screen.blit(background_img, (0, 0)) # background first
    # screen.blit(sun_img, (100, 100)) #comment displaying the sun as well


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.update()

##conclusion: the image can we scaled up or down to fit the screen

# %%
#to load the player

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True
# player_img = pygame.image.load('./Assets/Character/Frame 1.png')
player_img = pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png'), (100, 140))##replacing the sun with the player
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) #changed the size of the object to fit the screen

while running == True:
    
    screen.blit(background_img, (0, 0)) # background first
    screen.blit(player_img, (300, 100)) #player is getting rendered in the forground, since first the background is displayed and this 


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.flip()


##conclusion: the concept of foreground and background

# %%
#attach a rect to the player and explain the concept of rectangle

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True

player_img = pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png'), (100, 140))##replacing the sun with the player
player_rect = player_img.get_rect(center = (600,300) )
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

while running == True:
    
    screen.blit(background_img, (0, 0)) # background first
    screen.blit(player_img, (100, 100)) #player is getting rendered in the forground, since first the background is displayed and this 
    pygame.draw.rect(screen,"red", player_rect)


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.flip()

##conclusion: the player rect which should be around the player is nowhere close to the player

# %%
#attach a rect to the player and explain the concept of rectangle

#so we define a few constant for the player x position and player y position

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

PLAYER_X_POSITION = 300
PLAYER_Y_POSITION = 500 #explain how the higher the value of y, lower we go in the screen

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True

player_img = pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png'), (100, 140))##replacing the sun with the player
player_rect = player_img.get_rect(center = (PLAYER_X_POSITION,PLAYER_Y_POSITION) )
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

while running == True:
    
    screen.blit(background_img, (0, 0)) # background first
    screen.blit(player_img, player_rect) #instead of using the x and the y position, now we will be using the player_rect instead
    # pygame.draw.rect(screen,"red", player_rect)


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.flip()

##conclusion: the player rect which should be around the player is nowhere close to the player

# %%
#move the character along the x axis

import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

PLAYER_X_POSITION = 300
PLAYER_Y_POSITION = 500

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

running = True

player_img = pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png'), (100, 140))
player_rect = player_img.get_rect(center = (PLAYER_X_POSITION,PLAYER_Y_POSITION) )
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 


clock = pygame.time.Clock()

while running == True:
    
    # Move 50 pixels per second
    PLAYER_X_POSITION += .5

    screen.blit(background_img, (0, 0)) 
    player_rect = player_img.get_rect(center = (PLAYER_X_POSITION,PLAYER_Y_POSITION) )
    screen.blit(player_img, player_rect)
    #pygame.draw.rect(screen,"red", player_rect)


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
    pygame.display.flip()

##conclusion: the player rect changes its value in each frame, and give the illusion of the movement

# %%
#attach a rect to the player and explain the concept of rectangle

#so we define a few constant for the player x position and player y position



import pygame

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

PLAYER_X_POSITION = 300
PLAYER_Y_POSITION = 500 #explain how the higher the value of y, lower we go in the screen

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 2")

#game loop
running = True

player_img = pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png'), (100, 140))##replacing the sun with the player
player_rect = player_img.get_rect(center = (PLAYER_X_POSITION,PLAYER_Y_POSITION) )
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock
while running == True:
    
    PLAYER_X_POSITION = PLAYER_X_POSITION +5
    player_rect = player_img.get_rect(center = (PLAYER_X_POSITION,PLAYER_Y_POSITION) )
    screen.blit(background_img, (0, 0)) # background first
    screen.blit(player_img, player_rect) #instead of using the x and the y position, now we will be using the player_rect instead
    # pygame.draw.rect(screen,"red", player_rect)

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    pygame.display.flip()


##conclusion: the player rect which should be around the player is nowhere close to the player
