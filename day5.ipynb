# %% [markdown]
# adding movement to the player sprite

# %%
# Day 5: Adding movement to the Player sprite (jumping upwards only)

import pygame

# NEW PART: Define a Player class that handles both normal and jumping animations
class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()
        
        # NEW PART: list to store normal running/walking sprites for animation
        self.sprites = []
        self.current_sprite = 0
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 1.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 2.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 3.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 4.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 5.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 6.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 7.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 8.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 9.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 10.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 11.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 12.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 13.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 14.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 15.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 16.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 17.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 18.png').convert_alpha(), (100, 150)))
        self.sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Character/Frame 19.png').convert_alpha(), (100, 150)))

        # NEW PART: list to store jump sprites
        self.jump_sprites = []
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 1.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 2.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 3.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 4.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 5.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 6.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 7.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 8.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 9.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 10.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 11.png').convert_alpha(), (100, 140)))
        self.jump_sprites.append(pygame.transform.scale(pygame.image.load('./Assets/Jump/Jump_frame 12.png').convert_alpha(), (100, 140)))
        
        # NEW PART: set initial sprite as the first jump frame
        self.image = self.jump_sprites[0]

        # NEW PART: character starting position and rect
        self.character_x_position = 300
        self.character_y_position = 500
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

        # NEW PART: jump variables
        self.y_velocity = 15
        self.y_gravity = 0.5
        self.jump_height = 15
        self.jumping = False

    # NEW PART: animate player depending on jumping or normal state
    def animate(self):
        if self.jumping:
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))
        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # NEW PART: handle input (SPACE key for jumping)
    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            # Move the player upwards
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                # Reset jump after peak
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # NEW PART: update method called every frame
    def update(self):
        self.player_input()
        self.animate()


# NEW PART: screen setup
SCREEN_WIDTH = 1280
SCREEN_HEIGHT = 720
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 5")

player_object = Player()

# NEW PART: Use GroupSingle to manage single player sprite
player = pygame.sprite.GroupSingle()
player.add(player_object)

running = True
background_img = pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png"), (SCREEN_WIDTH, SCREEN_HEIGHT)) 
clock = pygame.time.Clock()

jumping = False
y_velocity = 20
y_gravity = 1
jump_height = 20

while running:
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    pygame.display.flip()


## Conclusion:
# - We detect key presses using pygame.key.get_pressed()
# - SPACE triggers jump (upward movement only)
# - Animate function handles switching between running and jumping frames
# - Movement is done by changing y-position and applying velocity + gravity

# %%
# Day 5: Adding movement to the Player sprite (jumping upwards only, using loops for sprite loading)

import pygame

# NEW PART: Define a Player class that handles both normal and jumping animations
class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()
        
        # NEW PART: list to store normal running/walking sprites (loaded using a loop)
        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):  # loads Frame 1.png to Frame 19.png
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        # NEW PART: list to store jump sprites (loaded using a loop)
        self.jump_sprites = []
        for i in range(1, 13):  # loads Jump_frame 1.png to Jump_frame 12.png
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        # NEW PART: set initial sprite as the first jump frame
        self.image = self.jump_sprites[0]

        # NEW PART: character starting position and rect
        self.character_x_position = 300
        self.character_y_position = 500
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

        self.y_velocity = 15
        self.y_gravity = 0.5
        self.jump_height = 15
        self.jumping = False

    def animate(self):
        if self.jumping:
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0
            self.image = self.jump_sprites[int(self.current_sprite)]
        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]

        # Update rect after sprite change
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # NEW PART: handle input (SPACE key for jumping)
    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            # Move the player upwards
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                # Reset jump after peak
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # NEW PART: update method called every frame
    def update(self):
        self.player_input()
        self.animate()


SCREEN_WIDTH = 1280
SCREEN_HEIGHT = 720
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 5")

# NEW PART: Initialize the player object
player_object = Player()

# NEW PART: Use GroupSingle to manage single player sprite
player = pygame.sprite.GroupSingle()
player.add(player_object)

# NEW PART: background setup
running = True
background_img = pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png"), (SCREEN_WIDTH, SCREEN_HEIGHT)) 
clock = pygame.time.Clock()

jumping = False
y_velocity = 20
y_gravity = 1
jump_height = 20

# Main game loop
while running:
    dt = clock.tick(60) 

    # Handle quit events
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    # Background rendering
    screen.blit(background_img, (0, 0))  

    # Draw and update player sprite
    player.draw(screen)
    player.update()

    # Refresh screen
    pygame.display.flip()


## Conclusion:
# - Used loops to load character and jump sprites efficiently
# - Player jumps only upward when SPACE is pressed
# - Animate function cycles through correct sprite frames
# - Cleaner and shorter code compared to manually appending each sprite

# %% [markdown]
# Adding the enemy object as well

# %%
# Day 6: Adding the enemy (obstacle) sprite

import pygame

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20): 
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]

        self.character_x_position = 300
        self.character_y_position = 500
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

        self.y_velocity = 15
        self.y_gravity = 0.5
        self.jump_height = 15
        self.jumping = False

    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]

        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()


# NEW PART: Define an Obstacle (enemy) class
class Obstacle(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        # Load enemy image and scale it
        self.image = pygame.transform.scale(
            pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), 
            (200, 200)
        )
        
        # NEW PART: initial position and rect
        self.character_x_position = 600
        self.character_y_position = 525
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # NEW PART: update obstacle (moves left every frame)
    def update(self):
        self.rect.x -= 1


SCREEN_WIDTH = 1280
SCREEN_HEIGHT = 720
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")

player_object = Player()
player = pygame.sprite.GroupSingle()
player.add(player_object)

# NEW PART: initialize the enemy sprite
obstacle_object = Obstacle()
obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(obstacle_object)

running = True
background_img = pygame.transform.scale(
    pygame.image.load("./Assets/BG/bg 01.png"), 
    (SCREEN_WIDTH, SCREEN_HEIGHT)
) 
clock = pygame.time.Clock()

jumping = False
y_velocity = 20
y_gravity = 1
jump_height = 20

# Main game loop
while running:
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    # NEW PART: Draw and update obstacle
    obstacle_group.draw(screen)
    obstacle_group.update()

    # Refresh screen
    pygame.display.flip()


## Conclusion:
# - Introduced Obstacle class as an enemy sprite
# - Enemy is drawn using its own GroupSingle
# - Enemy continuously moves left across the screen
# - Player can still jump with SPACE key

# %% [markdown]
# Collision: BOOM!

# %%
#Adding the enemy collision
import pygame

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100 # move the player to the left a bit
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self,):
        super().__init__()

        # load single obstacle image
        self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        self.character_x_position= 600
        self.character_y_position= 525
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def update(self): 
        self.rect.x -=7  # move obstacle left (speed)


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 5")


# --- Groups ---
player_object = Player()
player = pygame.sprite.GroupSingle()
player.add(player_object)

obstacle_object = Obstacle()
obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(obstacle_object)


running = True
background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 
clock = pygame.time.Clock()

jumping = False
y_velocity = 20
y_gravity = 1
jump_height = 20


# --- Collision detection function ---
def collisions():
    # pygame.sprite.groupcollide checks for collisions between two sprite groups
    # arguments: (sprite_group1, sprite_group2, dokill1, dokill2)
    # Here: if player hits obstacle -> both are removed (True, True)
    if pygame.sprite.groupcollide(player, obstacle_group, True, True):
        return False  # collision happened -> stop game
    else:
        return True   # no collision -> keep running
    

while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()  # check for collision each frame

    pygame.display.flip()

pygame.quit()
    
## conclusion: we determine which key was pressed, check if it's space, and if so then move the player up

# %% [markdown]
# Removing the enemy objects that are out of bounds as well

# %%
#Adding the enemy collision
import pygame


class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100# move the player to the left a bit
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self,):
        super().__init__()

        self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        self.character_x_position= 600
        self.character_y_position= 525
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def update(self): 
        self.rect.x -=7 


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720


screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 5")


player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)

obstacle_object = Obstacle()
obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(obstacle_object)

running = True


background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False

y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
    # Detect collision between player and obstacle
    # - player (GroupSingle) vs obstacle_group (GroupSingle)
    # - If they collide, both are removed (True, True) → game ends (return False)
    if pygame.sprite.groupcollide(player, obstacle_group, True, True):
        return False
    
    # Check if obstacle exists in the group
    if obstacle_group.__len__() > 0: 
        print(obstacle_group.sprite.rect.x)  # Debug: print obstacle's x position

        # If the obstacle has fully moved off-screen (x < -100) → recycle it
        if obstacle_group.sprite.rect.x < -100:
            obstacle_group.sprites().pop(0).kill()   # Remove old obstacle
            obstacle_object.rect.x = 1400            # Reset position to the right
            obstacle_group.add(obstacle_object)      # Add it back to the group
            return True  # Keep game running
    
    return True  # No collision → game continues
    

while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()
    
    pygame.display.flip()


pygame.quit()
