# %%
#Adding multiple Enemy types
import pygame
import random

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self, type):
        super().__init__()
        self.type = type  # Type decides which image to use

        # Load different obstacle images depending on type
        if self.type == "obstacle 1":
            self.image = pygame.transform.scale(
                pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        elif self.type == "obstacle 2":
            self.image = pygame.transform.scale(
                pygame.image.load('./Assets/Obstacles/Obstacle 02.png').convert_alpha(), (200, 200))
        elif self.type == "obstacle 3":
            self.image = pygame.transform.scale(
                pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), (200, 200))

        # Starting position (off to the right)
        self.character_x_position = 700
        self.character_y_position = 525
        self.rect = self.image.get_rect(center=(self.character_x_position, self.character_y_position))

    # Move obstacle to the left
    def update(self):
        self.rect.x -= 7


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720


screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")


player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)

# Create different obstacle types
obstacle_1 = Obstacle(type='obstacle 1')
obstacle_2 = Obstacle(type='obstacle 2')
obstacle_3 = Obstacle(type='obstacle 3')


# Add one random obstacle at a time
obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_1)))

running = True

background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False

y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
    if pygame.sprite.groupcollide(player, obstacle_group, False, True):
        return True
    
    if obstacle_group.__len__() > 0: 
        if obstacle_group.sprite.rect.x < -100:
            obstacle_group.sprites().pop(0).kill()
            return True
    
    return True
    

while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()
    
    pygame.display.flip()
pygame.quit()

# %% [markdown]
# Regerate enemy after collision

# %%
import pygame
import random

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self, type):
        super().__init__()

        self.type = type

        if self.type == "obstacle 1":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        elif self.type == "obstacle 2":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 02.png').convert_alpha(), (200, 200))

        elif self.type == "obstacle 3":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), (200, 200))

        
        self.character_x_position= 700
        self.character_y_position= 525
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def update(self):
        self.rect.x -= 7


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720


screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")

player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)


obstacle_1= Obstacle(type='obstacle 1')
obstacle_2 = Obstacle(type='obstacle 2')
obstacle_3 = Obstacle(type='obstacle 3')  

obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_3)))

running = True

background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False


y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
    # Case 1: If player collides with obstacle
    if pygame.sprite.groupcollide(player, obstacle_group, False, True):
        # Enemy object is removed on collision, so we regenerate it here

        # Pick a new random obstacle type (1, 2, or 3)
        obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))

        # Add the new obstacle back into the obstacle group
        obstacle_group.add(obstacle)

        # Return False → lets main loop know collision happened
        # (You can use this to reduce lives, reset game, etc.)
        return True  

    # Case 2: If obstacle goes off-screen (moves left outside visible window)
    if obstacle_group.__len__() > 0: 
        if obstacle_group.sprite.rect.x < -100:
            # Remove the old obstacle once it’s outside the screen
            obstacle_group.sprites().pop(0).kill()

            # Generate a new random obstacle to keep the game running
            obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))
            obstacle_group.add(obstacle)

            return True  # Game continues normally

    # If no collision and obstacle is still inside screen → just continue
    return True


while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()
    
    pygame.display.flip()

# %% [markdown]
# Adding randomness to the position of enemy spawing

# %%
import pygame
import random

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100# move the player to the left a bit
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self, type):
        super().__init__()

        self.type = type

        if self.type == "obstacle 1":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        elif self.type == "obstacle 2":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 02.png').convert_alpha(), (200, 200))

        elif self.type == "obstacle 3":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), (200, 200))

        
        self.character_x_position= 700
        self.character_y_position= 525
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def update(self):
        self.rect.x -= 7


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720


screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")


player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)



obstacle_1= Obstacle(type='obstacle 1')
obstacle_2 = Obstacle(type='obstacle 2')
obstacle_3 = Obstacle(type='obstacle 3')

obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_3)))

running = True

background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False

y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
 
    if pygame.sprite.groupcollide(player, obstacle_group, False, True):
        # Case 1: Collision between player and obstacle
        # After collision → spawn a new random obstacle

        obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))

        # NEW: Randomize the x position of the new obstacle
        #   - obstacle.character_x_position is the default spawn (e.g., 700)
        #   - random.randint(0, 200) adds some randomness (spawns between 700-900)
        obstacle.rect.x = obstacle.character_x_position + random.randint(0, 200)

        # Add the regenerated obstacle back into the group
        obstacle_group.add(obstacle)

        return True
    
    if obstacle_group.__len__() > 0: 
        if obstacle_group.sprite.rect.x < -100:
            # Case 2: Obstacle leaves the screen → remove it
            obstacle_group.sprites().pop(0).kill()

            # Spawn a new obstacle at a slightly random x position
            obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))
            obstacle.rect.x = obstacle.character_x_position + random.randint(0, 200)

            # Add it to the group
            obstacle_group.add(obstacle)

            return True
    
    # Default: No collision, obstacle still visible
    return True


while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()
    
    pygame.display.flip()

# %% [markdown]
# Getting the enemy to spawn from outside the screen

# %%
import pygame
import random

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Obstacle(pygame.sprite.Sprite):
    def __init__(self, type):
        super().__init__()

        self.type = type

        if self.type == "obstacle 1":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        elif self.type == "obstacle 2":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 02.png').convert_alpha(), (200, 200))

        elif self.type == "obstacle 3":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), (200, 200))

        
        self.character_x_position= 1400 #modfiy the starting position to have a value higher than the screen resolution of 1280 width;
        self.character_y_position= 525
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def update(self):
        self.rect.x -= 7

SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")

player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)


obstacle_1= Obstacle(type='obstacle 1')
obstacle_2 = Obstacle(type='obstacle 2')
obstacle_3 = Obstacle(type='obstacle 3')

obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_3)))

running = True

background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False

y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
 
    if pygame.sprite.groupcollide(player, obstacle_group, False, True):
        # Create a new random obstacle
        obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))

        # NEW: Ensure obstacle respawns OUTSIDE the screen
        # Randomize x spawn position between SCREEN_WIDTH + 100 and SCREEN_WIDTH + 500
        obstacle.rect.x = SCREEN_WIDTH + random.randint(100, 500)

        obstacle_group.add(obstacle)
        return True
    
    if obstacle_group.__len__() > 0: 
        if obstacle_group.sprite.rect.x < -100:
            obstacle_group.sprites().pop(0).kill()

            # Same logic: spawn outside screen
            obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))
            obstacle.rect.x = SCREEN_WIDTH + random.randint(100, 500)

            obstacle_group.add(obstacle)
            return True
    
    return True


while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    running = collisions()
    
    pygame.display.flip()

# %% [markdown]
# Adding Reward

# %%
#Demonstarte how creating class makes it easier to reproduce the Object into different types
import pygame
import random

class Player(pygame.sprite.Sprite):
    def __init__(self):
        super().__init__()

        self.sprites = []
        self.current_sprite = 0
        for i in range(1, 20):
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Character/Frame {i}.png').convert_alpha(), 
                (100, 150)
            )
            self.sprites.append(sprite)

        self.jump_sprites = []
        for i in range(1, 13):  
            sprite = pygame.transform.scale(
                pygame.image.load(f'./Assets/Jump/Jump_frame {i}.png').convert_alpha(), 
                (100, 140)
            )
            self.jump_sprites.append(sprite)
        
        self.image = self.jump_sprites[0]
        self.character_x_position= 100
        self.character_y_position= 500
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))
        self.y_velocity = 20
        self.y_gravity = 0.5
        self.jump_height = 20
        self.jumping = False

    
    def animate(self):
        if self.jumping:    
            self.current_sprite += 0.5
            if self.current_sprite >= len(self.jump_sprites):
                self.current_sprite = 0 
            self.image = self.jump_sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

        else:
            self.current_sprite += 1
            if self.current_sprite >= len(self.sprites):
                self.current_sprite = 0
            self.image = self.sprites[int(self.current_sprite)]
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))

    def player_input(self):
        keys = pygame.key.get_pressed()

        if keys[pygame.K_SPACE] and not self.jumping:
            self.jumping = True
        
        if self.jumping:
            self.character_y_position -= self.y_velocity
            self.y_velocity -= self.y_gravity
            if self.y_velocity < -self.jump_height:
                self.y_velocity = self.jump_height
                self.jumping = False
            self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))     

    def update(self):
        self.player_input()
        self.animate()
 

class Item(pygame.sprite.Sprite):
    #create a parent class so that the child classes can have similar characteristics
    def __init__(self, x, y):
        super().__init__()
        self.character_x_position = x
        self.character_y_position = y

    def update(self):
        self.rect.x -= 6


class Obstacle(Item):
    def __init__(self, item_type):
        super().__init__(x = 1400, y = 525)

        self.item_type = item_type

        if self.item_type == "obstacle 1":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 01.png').convert_alpha(), (200, 200))
        
        elif self.item_type == "obstacle 2":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 02.png').convert_alpha(), (200, 200))

        elif self.item_type == "obstacle 3":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Obstacles/Obstacle 03.png').convert_alpha(), (200, 200))

        
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))


class Reward(Item):
    def __init__(self, item_type):
        super().__init__(x = 1500, y = 500)

        self.item_type = item_type

        if self.item_type == "point 1":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Points/point 01.png').convert_alpha(), (100, 100))

        elif self.item_type == "point 2":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Points/point 02.png').convert_alpha(), (100, 100))

        elif self.item_type == "point 3":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Points/point 03.png').convert_alpha(), (120, 120))

        elif self.item_type == "point 4":
            self.image = pygame.transform.scale(pygame.image.load('./Assets/Points/point 05.png').convert_alpha(), (120, 120))

        
        self.rect = self.image.get_rect(center = (self.character_x_position, self.character_y_position))


SCREEN_WIDTH= 1280
SCREEN_HEIGHT = 720

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("day 6")

player_object = Player()

player = pygame.sprite.GroupSingle()
player.add(player_object)

obstacle_1= Obstacle(item_type='obstacle 1')
obstacle_2 = Obstacle(item_type='obstacle 2')
obstacle_3 = Obstacle(item_type='obstacle 3')
obstacle_group = pygame.sprite.GroupSingle()
obstacle_group.add(random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_3)))

reward_1= Reward(item_type='point 1')
reward_2 = Reward(item_type='point 2')
reward_3 = Reward(item_type='point 3')
reward_4 = Reward(item_type='point 4')

reward_group = pygame.sprite.GroupSingle()
reward_group.add(random.choice((reward_1, reward_2, reward_3, reward_3, reward_4)))

running = True

background_img =  pygame.transform.scale(pygame.image.load("./Assets/BG/bg 01.png") , (SCREEN_WIDTH, SCREEN_HEIGHT)) 

clock = pygame.time.Clock()

jumping = False

y_velocity = 20
y_gravity = 1
jump_height = 20

def collisions():
    #handle the collision between the player and the obstacle
    if pygame.sprite.groupcollide(player, obstacle_group, False, True):
        obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3, obstacle_2))
        obstacle.rect.x = obstacle.character_x_position + random.randint(0, 200)
        obstacle_group.add(obstacle)
        return False
    
    #handle the collision between the reward and the obstacle
    if pygame.sprite.groupcollide(reward_group, obstacle_group, False, False):
        obstacle_group.sprite.rect.x += random.randint(100, 500)

    
    #handle the collision between the player and the reward
    if pygame.sprite.groupcollide(player, reward_group, False, True):
        reward = random.choice((reward_1, reward_2, reward_3, reward_3, reward_4))
        reward.rect.x = reward.character_x_position + random.randint(0, 260)
        reward_group.add(reward)

    #handle the scenario where the obstacle goes out of screen    
    if obstacle_group.__len__() > 0: 
        if obstacle_group.sprite.rect.x < -100:
            obstacle_group.sprites().pop(0).kill()
            obstacle = random.choice((obstacle_1, obstacle_2, obstacle_3,  obstacle_2))
            obstacle.rect.x = obstacle.character_x_position + random.randint(0, 200)
            obstacle_group.add(obstacle)
            return True

    #handle the scenario where the reward goes out of screen
    if reward_group.__len__() > 0: 
        if reward_group.sprite.rect.x < -100:
            reward_group.sprites().pop(0).kill()
            reward = random.choice((reward_1, reward_2, reward_3, reward_3, reward_4))
            reward.rect.x = reward.character_x_position + random.randint(0, 260)
            reward_group.add(reward)
            return True
        
    return True


while running == True:
    
    dt = clock.tick(60) 

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()

    keys_pressed = pygame.key.get_pressed()

    if keys_pressed[pygame.K_SPACE]:
        jumping = True

    screen.blit(background_img, (0, 0))  

    player.draw(screen)
    player.update()

    obstacle_group.draw(screen)
    obstacle_group.update()

    reward_group.draw(screen)
    reward_group.update()

    running = collisions()
    
    pygame.display.flip()
